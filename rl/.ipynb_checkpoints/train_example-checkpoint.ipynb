# %%
from models import ValueNetwork
from agents import ValueAgent
from buffers import PostgreSQLReplayBuffer

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot(iteration, losses, values):
    clear_output(True)
    plt.figure(figsize=(20,5))
    plt.subplot(131)
    plt.title('Iteration %s. Loss: %s' % (iteration, losses[-1]))
    plt.plot(losses)
    plt.subplot(132)
    plt.title('Iteration %s. Mean V: %s' % (iteration, values[-1]))
    plt.plot(values)
    plt.show()

# %%
buffer = PostgreSQLReplayBuffer()

# %%
agent = ValueAgent(ValueNetwork, buffer)

# %%
losses = []
values = []
for sample in range(100):
    loss, mean_v = agent.train()
    losses.append(loss)
    values.append(mean_v)
    plot(sample, losses, values)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5b3bd016a756> in <module>
#       2 values = []
#       3 for sample in range(100):
# ----> 4     loss, mean_v = agent.train()
#       5     losses.append(loss)
#       6     values.append(mean_v)
#
# ~/Downloads/Projects/Competitions/DiDi/kdd-didi/rl/agents.py in train(self)
#      49
#      50     def train(self):
# ---> 51         state, reward, next_state, info = self.replay_buffer.sample(self.batch_size)
#      52
#      53         state = torch.FloatTensor(state).to(self.device)
#
# ~/Downloads/Projects/Competitions/DiDi/kdd-didi/rl/buffers.py in sample(self, batch_size)
#      80         batch = []
#      81         with self.con.connect() as connection:
# ---> 82             sample = connection.execute(self.query % batch_size)
#      83             for row in sample:
# ...
